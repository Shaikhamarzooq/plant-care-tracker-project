# %%
import plant_tracker_project

# %%
plant_tracker_project.main()
# Out:
# 1. Add a new plant to the collection.
# 2. Record a plant care activity.
# 3. View plants due for care.
# 4. Search plants by name or location.
# 5. View all plants.
# 6. Add photo for a plant.
# 7. ask the program for diagnosis and symptoms.
